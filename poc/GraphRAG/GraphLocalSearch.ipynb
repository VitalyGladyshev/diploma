# %% [markdown]
# # Локальный поиск в графе - Graph Local Search

# %%
import pandas as pd
import os
import tiktoken

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from graphrag.query.context_builder.entity_extraction import EntityVectorStoreKey
from graphrag.query.indexer_adapters import (
    read_indexer_covariates,
    read_indexer_entities,
    read_indexer_relationships,
    read_indexer_reports,
    read_indexer_text_units,
)
from graphrag.config.enums import ModelType
from graphrag.config.models.language_model_config import LanguageModelConfig
from graphrag.language_model.manager import ModelManager
from graphrag.query.question_gen.local_gen import LocalQuestionGen
from graphrag.query.structured_search.local_search.mixed_context import (
    LocalSearchMixedContext,
)
from graphrag.query.structured_search.local_search.search import LocalSearch
from graphrag.vector_stores.lancedb import LanceDBVectorStore

# %%
GRAPHRAG_DIR = os.path.join(os.getcwd(), "ragtestour")
INPUT_DIR = os.path.join(GRAPHRAG_DIR, "output")
LANCEDB_URI = os.path.join(INPUT_DIR, "lancedb")

# %%
COMMUNITY_REPORT_TABLE = "community_reports"
COMMUNITY_TABLE = "communities"
ENTITY_TABLE = "entities"
RELATIONSHIP_TABLE = "relationships"
COVARIATE_TABLE = "covariates"
TEXT_UNIT_TABLE = "text_units"
COMMUNITY_LEVEL = 2

# %%
entity_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_TABLE}.parquet")
community_df = pd.read_parquet(f"{INPUT_DIR}/{COMMUNITY_TABLE}.parquet")

entities = read_indexer_entities(entity_df, community_df, COMMUNITY_LEVEL)

relationship_df = pd.read_parquet(f"{INPUT_DIR}/{RELATIONSHIP_TABLE}.parquet")
relationships = read_indexer_relationships(relationship_df)

report_df = pd.read_parquet(f"{INPUT_DIR}/{COMMUNITY_REPORT_TABLE}.parquet")
reports = read_indexer_reports(report_df, community_df, COMMUNITY_LEVEL)

text_unit_df = pd.read_parquet(f"{INPUT_DIR}/{TEXT_UNIT_TABLE}.parquet")
text_units = read_indexer_text_units(text_unit_df)

# %%
description_embedding_store = LanceDBVectorStore(
    collection_name="default-entity-description",
)
description_embedding_store.connect(db_uri=LANCEDB_URI)

full_content_embedding_store = LanceDBVectorStore(
    collection_name="default-community-full_content",
)
full_content_embedding_store.connect(db_uri=LANCEDB_URI)

# %%
# api_key_llm = "not-needed"
api_key = os.environ["GRAPHRAG_API_KEY"]
# api_key

llm_model = "gpt-4o-mini" # "gemma-3-27b-it@q4_k_m"
embedding_model = "text-embedding-3-small"

# %%
chat_config = LanguageModelConfig(
    api_key=api_key,
    api_base="https://api.vsegpt.ru/v1", # "http://172.21.16.141:1234/v1",
    type=ModelType.OpenAIChat,
    model=llm_model,
    max_retries=20,
)
chat_model = ModelManager().get_or_create_chat_model(
    name="local_search",
    model_type=ModelType.OpenAIChat,
    config=chat_config,
)

token_encoder = tiktoken.encoding_for_model(llm_model)

embedding_config = LanguageModelConfig(
    api_key=api_key,
    api_base="https://api.vsegpt.ru/v1",
    type=ModelType.OpenAIEmbedding,
    model=embedding_model,
    max_retries=20,
)

text_embedder = ModelManager().get_or_create_embedding_model(
    name="local_search_embedding",
    model_type=ModelType.OpenAIEmbedding,
    config=embedding_config,
)

# %%
context_builder = LocalSearchMixedContext(
    community_reports=reports,
    text_units=text_units,
    entities=entities,
    relationships=relationships,
    # if you did not run covariates during indexing, set this to None
    covariates=None, #covariates,
    entity_text_embeddings=description_embedding_store,
    embedding_vectorstore_key=EntityVectorStoreKey.ID,  # if the vectorstore uses entity title as ids, set this to EntityVectorStoreKey.TITLE
    text_embedder=text_embedder,
    token_encoder=token_encoder,
)

# %%
local_context_params = {
    "text_unit_prop": 0.5,
    "community_prop": 0.1,
    "conversation_history_max_turns": 5,
    "conversation_history_user_turns_only": True,
    "top_k_mapped_entities": 10,
    "top_k_relationships": 10,
    "include_entity_rank": True,
    "include_relationship_weight": True,
    "include_community_rank": False,
    "return_candidate_context": False,
    "embedding_vectorstore_key": EntityVectorStoreKey.ID,  # set this to EntityVectorStoreKey.TITLE if the vectorstore uses entity title as ids
    "max_tokens": 12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
}

model_params = {
    "max_tokens": 2_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 1000=1500)
    "temperature": 0.0,
}

# %%
search_engine = LocalSearch(
    model=chat_model,
    context_builder=context_builder,
    token_encoder=token_encoder,
    model_params=model_params,
    context_builder_params=local_context_params,
    response_type="multiple paragraphs",  # free form text describing the response type and format, can be anything, e.g. prioritized list, single paragraph, multiple paragraphs, multiple-page report
)

# %%
import time

# %%
start = time.time()

result = await search_engine.search("Что такое межрасчётные выплаты?")

end = time.time()
print(f"Длительность: {(end - start):.3f} сек.")
# Out:
# Длительность: 12.991 сек.

# %%
print(result.response)
# Out:
# ## Определение межрасчётных выплат
#
# Межрасчётные выплаты представляют собой финансовые средства, которые выплачиваются работникам вне регулярного расчётного периода. Эти выплаты могут включать различные виды компенсаций, такие как выплаты за неиспользованные дни отпуска, дополнительные выплаты в связи с изменениями в трудовых условиях или другие разовые начисления, которые не входят в стандартный расчёт заработной платы [Data: Entities (276); Relationships (1324, 320)].
#
# ## Процессы, связанные с межрасчётными выплатами
#
# Межрасчётные выплаты инициируются на основании различных документов, таких как приказ о предоставлении отпуска. После подписания такого приказа начинается процесс формирования межрасчётных выплат, что подчеркивает важность соблюдения установленных процедур в управлении трудовыми ресурсами [Data: Relationships (1302, 955, 581)].
#
# Кроме того, межрасчётные выплаты могут быть частью расчёта авансов, что позволяет обеспечить дополнительные выплаты между основными расчётами. Это также включает в себя компенсацию за неиспользованные дни отпуска при увольнении, что является важным аспектом финансового управления в организации [Data: Relationships (545, 1546, 1993)].
#
# ## Важность межрасчётных выплат
#
# Эти выплаты играют ключевую роль в поддержании финансовой стабильности и удовлетворенности сотрудников. Они обеспечивают гибкость в управлении заработной платой и позволяют учитывать индивидуальные обстоятельства работников, такие как временная нетрудоспособность или изменения в трудовых условиях. Таким образом, межрасчётные выплаты способствуют более эффективному управлению трудовыми ресурсами и повышению доверия сотрудников к организации [Data: Reports (20); Entities (459, 423)].
#
# В заключение, межрасчётные выплаты являются важным элементом системы расчёта заработной платы, обеспечивая дополнительные финансовые средства для работников в различных ситуациях, что подчеркивает их значимость в рамках управления персоналом.

# %%
result.context_data.keys()
# Out:
# dict_keys(['reports', 'relationships', 'entities', 'sources'])

# %%
result.context_data['entities']
# Out:
# dict_keys(['reports', 'relationships', 'entities', 'sources'])

# %%
result.context_data['relationships']
# Out:
#       id                                            source  \
# 0    548                               ПЕРЕРАСЧЕТ ЗАРПЛАТЫ
# 1   1324                              МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 2    320                                          ЗАРПЛАТА
# 3    329                                РАЗОВЫЕ НАЧИСЛЕНИЯ
# 4    321                                          ЗАРПЛАТА
# 5   1321                        РЕГУЛЯРНЫЙ РАСЧЕТ ЗАРПЛАТЫ
# 6    316                                          ЗАРПЛАТА
# 7   2550                                               ЭТЖ
# 8   1073                                               ЭТЖ
# 9    330                                РАЗОВЫЕ НАЧИСЛЕНИЯ
# 10  1302                              МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 11   955                   ПРИКАЗ О ПРЕДОСТАВЛЕНИИ ОТПУСКА
# 12   582                                 ОТПУСКНЫЕ ВЫПЛАТЫ
# 13   581                           ГРУППА РАСЧЕТА ЗАРПЛАТЫ
# 14   613                                  РАСЧЕТНАЯ ГРУППА
# 15  1320                 ФОРМИРОВАНИЕ ЗАВЕРШАЮЩИХ ОПЕРАЦИЙ
# 16   612                                     УЧЕТ ЗАРПЛАТЫ
# 17   580                           ГРУППА РАСЧЕТА ЗАРПЛАТЫ
# 18  1317                 ФОРМИРОВАНИЕ ЗАВЕРШАЮЩИХ ОПЕРАЦИЙ
# 19  2039                              СПЕЦИАЛИСТ ПО КАДРАМ
# 20  1984                    ГБ. БУХГАЛТЕР РАСЧЕТНОЙ ГРУППЫ
# 21   326                              МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 22  1253                                     ПОДРАЗДЕЛЕНИЕ
# 23  1760                                           ВЫПЛАТЫ
# 24  1008                       ОТПУСК ПО УХОДУ ЗА РЕБЕНКОМ
# 25  2795                                         ВЕДОМОСТЬ
# 26  3163             ГБ. ФОРМИРОВАНИЕ ЗАВЕРШАЮЩИХ ОПЕРАЦИЙ
# 27   547                               ПЕРЕРАСЧЕТ ЗАРПЛАТЫ
# 28   578                             ДОПОЛНИТЕЛЬНЫЙ ОТПУСК
# 29   325                              МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 30  1546                              МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 31  1991                         ПРЕДВАРИТЕЛЬНЫЕ ВЕДОМОСТИ
# 32  1280                     ВЕДОМОСТЬ НА ВЫПЛАТУ ЗАРПЛАТЫ
# 33  1993                              МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 34  2043                               ПЕРЕРАСЧЕТ ЗАРПЛАТЫ
# 35   391                                            ТАБЕЛЬ
# 36   545                                    РАСЧЕТ АВАНСОВ
# 37  1303                              МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 38  1554                               КОМПЕНСАЦИЯ ОТПУСКА
# 39  1254                         ИНДИВИДУАЛЬНЫЙ ПЕРЕРАСЧЕТ
# 40  1281                     ВЕДОМОСТЬ НА ВЫПЛАТУ ЗАРПЛАТЫ
# 41   500                                           ВЫПЛАТЫ
# 42   759                                ЗОНАЛЬНАЯ НАДБАВКА
# 43  1186  СПЕЦИАЛИСТ ПО УЧЕТУ ВРЕМЕНИ, ОТРАБОТАННОГО В ОУТ
# 44  3165                                        НАЧИСЛЕНИЕ
# 45  2555                                                ТЖ
# 46  1111                                   ПЕРЕСЧЕТ ОПЛАТЫ
# 47  1870                                 ПРЕМИИ И НАДБАВКИ
# 48  3166                                        НАЧИСЛЕНИЕ
# 49  3167                                        НАЧИСЛЕНИЕ
# 50  1107                          КОРРЕКТИРУЮЩИЕ ДОКУМЕНТЫ
# 51   485                           РАСЧЕТ ЗАРАБОТНОЙ ПЛАТЫ
# 52  1751           ПОДРАЗДЕЛЕНИЕ "ПРОЧИЕ (99) – ВНЕ ШТАТА"
# 53   484                               ВТОРОЙ РАБОЧИЙ ДЕНЬ
# 54  1110                            КОД НАЧАЛА БОЛЬНИЧНОГО
#
#                                  target  \
# 0              ОРГАНИЗАЦИЯ ПЕРЕРАСЧЕТОВ
# 1                              ЗАРПЛАТА
# 2                  МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 3                              ЗАРПЛАТА
# 4                    РАЗОВЫЕ НАЧИСЛЕНИЯ
# 5                              ЗАРПЛАТА
# 6           ИЗМЕНЕНИЯ В СПОСОБАХ ВЫПЛАТ
# 7                     ПРЕМИИ И НАДБАВКИ
# 8                   ПЕРЕРАСЧЕТ ЗАРПЛАТЫ
# 9                                   ЭТЖ
# 10      ПРИКАЗ О ПРЕДОСТАВЛЕНИИ ОТПУСКА
# 11                 МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 12      ПРИКАЗ О ПРЕДОСТАВЛЕНИИ ОТПУСКА
# 13                 МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 14                   РАЗОВЫЕ НАЧИСЛЕНИЯ
# 15                 МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 16                     РАСЧЕТНАЯ ГРУППА
# 17                    ОТПУСКНЫЕ ВЫПЛАТЫ
# 18           РЕГУЛЯРНЫЙ РАСЧЕТ ЗАРПЛАТЫ
# 19                  ПЕРЕРАСЧЕТ ЗАРПЛАТЫ
# 20                 МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 21                              СИСТЕМА
# 22            ИНДИВИДУАЛЬНЫЙ ПЕРЕРАСЧЕТ
# 23                      РАСЧЕТ ЗАРПЛАТЫ
# 24                 МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 25                   РАЗОВЫЕ НАЧИСЛЕНИЯ
# 26                           НАЧИСЛЕНИЕ
# 27                УЧЕТ РАБОЧЕГО ВРЕМЕНИ
# 28                 МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 29          ДАННЫЕ ДЛЯ РАСЧЕТА ЗАРПЛАТЫ
# 30                          КОМПЕНСАЦИЯ
# 31                 МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 32             ОТВЕТСТВЕННЫЙ СПЕЦИАЛИСТ
# 33  ОКОНЧАТЕЛЬНЫЙ РАСЧЕТ ПРИ УВОЛЬНЕНИИ
# 34                            ТАБЕЛЬЩИК
# 35                    ПРЕМИИ И НАДБАВКИ
# 36                 МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 37                    РАСЧЕТНЫЕ ВЫПЛАТЫ
# 38                 МЕЖРАСЧЕТНЫЕ ВЫПЛАТЫ
# 39                        КОРРЕКТИРОВКА
# 40                            ВЕДОМОСТИ
# 41                                  ЯОК
# 42                    ПРЕМИИ И НАДБАВКИ
# 43                    ПРЕМИИ И НАДБАВКИ
# 44               МЕЖРАСЧЕТНАЯ ВЕДОМОСТЬ
# 45                    ПРЕМИИ И НАДБАВКИ
# 46             КОРРЕКТИРУЮЩИЕ ДОКУМЕНТЫ
# 47   ДОПЛАТА ЗА ИСПОЛНЕНИЕ ОБЯЗАННОСТЕЙ
# 48                     УДЕРЖАНИЕ В БАНК
# 49                    УДЕРЖАНИЕ В КАССУ
# 50                      ПЕРЕСЧЕТ ОПЛАТЫ
# 51                             ПРОВОДКИ
# 52                              ВЫПЛАТЫ
# 53              РАСЧЕТ ЗАРАБОТНОЙ ПЛАТЫ
# 54                      ПЕРЕСЧЕТ ОПЛАТЫ
#
#                                           description weight links  in_context
# 0   Организация перерасчетов связана с процессом п...    1.0     1        True
# 1   Межрасчетные выплаты представляют собой дополн...    1.0     4        True
# 2   Межрасчетные выплаты отражаются в системе и яв...    8.0     4        True
# 3   Разовые начисления влияют на расчет заработной...    8.0     4        True
# 4   Разовые начисления и удержания влияют на общую...    7.0     4        True
# 5   Регулярный расчет заработной платы включает в ...    9.0     4        True
# 6   Изменения в способах выплат влияют на процесс ...    1.0     4        True
# 7   Процесс ЭТЖ включает заполнение области премий...    8.0     3        True
# 8   Процесс перерасчета заработной платы включает ...    1.0     3        True
# 9   Процесс расчета заработной платы включает разо...    8.0     3        True
# 10  Межрасчетные выплаты начинаются после подписан...    1.0     2        True
# 11  ПРИКАЗ О ПРЕДОСТАВЛЕНИИ ОТПУСКА инициирует про...   16.0     2        True
# 12  ОТПУСКНЫЕ ВЫПЛАТЫ и ПРИКАЗ О ПРЕДОСТАВЛЕНИИ ОТ...   10.0     2        True
# 13  Группа расчета заработной платы отвечает за пр...    6.0     2        True
# 14  Бухгалтер расчетной группы вводит разовые начи...    1.0     2        True
# 15  ФОРМИРОВАНИЕ ЗАВЕРШАЮЩИХ ОПЕРАЦИЙ и МЕЖРАСЧЕТН...    2.0     2        True
# 16  Расчетная группа отвечает за процесс расчета з...    9.0     2        True
# 17  Группа расчета заработной платы отвечает за пр...   10.0     2        True
# 18  Формирование завершающих операций включает в с...    8.0     2        True
# 19  Специалист по кадрам организует перерасчеты за...    1.0     1        True
# 20  Бухгалтер расчетной группы участвует в процесс...    9.0     1        True
# 21  Межрасчетные выплаты также обрабатываются и от...    1.0     1        True
# 22  Индивидуальный перерасчет сотрудников осуществ...    1.0     1        True
# 23  Выплаты прочим лицам не списочного состава свя...    1.0     1        True
# 24  Отпуск по уходу за ребенком является основание...    1.0     1        True
# 25  Ведомость включает разовые начисления для сотр...    8.0     1        True
# 26  Специалист отвечает за формирование начислений...    7.0     1        True
# 27  Процесс перерасчета заработной платы зависит о...    8.0     1        True
# 28  Дополнительный отпуск требует проведения межра...    1.0     1        True
# 29  Данные для расчета зарплаты также включают инф...    1.0     1        True
# 30  Межрасчетные выплаты включают в себя процесс к...    1.0     1        True
# 31  Предварительные ведомости содержат информацию ...    1.0     1        True
# 32  Ответственный специалист включает суммы в ведо...    7.0     1        True
# 33  Окончательный расчет при увольнении является о...    1.0     1        True
# 34  Табельщик может быть вовлечен в процесс перера...    1.0     1        True
# 35  Премии и надбавки учитываются в табелях рабоче...    6.0     1        True
# 36  Межрасчетные выплаты могут быть частью процесс...    6.0     1        True
# 37  Межрасчетные выплаты являются частью расчетных...    1.0     1        True
# 38  Компенсация отпуска выплачивается в рамках про...    1.0     1        True
# 39  Корректировка данных приводит к индивидуальном...    9.0     1        True
# 40  Ведомости включают в себя данные для ведомости...    7.0     1        True
# 41  ЯОК отвечает за выплаты, включая бюджетные суб...    1.0     1        True
# 42  Зональная надбавка определяется на основании д...    1.0     1        True
# 43  Специалист по учету времени заносит информацию...    1.0     1        True
# 44  Начисления для возмещения командировочных расх...    1.0     1        True
# 45  ТЖ фиксирует значения распределения премий и н...    8.0     1        True
# 46  Корректирующие документы запускают процесс пер...    9.0     1        True
# 47  Доплата за исполнение обязанностей временно от...    1.0     1        True
# 48  Начисления для возмещения командировочных расх...    7.0     1        True
# 49  Начисления для возмещения командировочных расх...    1.0     1        True
# 50  Пересчет оплаты запускается после восстановлен...    1.0     1        True
# 51  Процесс расчета заработной платы включает в се...    9.0     1        True
# 52  Выплаты прочим лицам не списочного состава про...    1.0     1        True
# 53  Расчет заработной платы осуществляется во втор...    8.0     1        True
# 54  Восстановление ссылки в поле «Код начала больн...    7.0     1        True

# %%
print(result.context_data['reports'].content[0])
# Out:
# # Human Resources Software Module Documentation Analysis
#
# The community focuses on the documentation processes within the human resources software module, particularly concerning payroll, employee onboarding, and compliance with labor regulations. Key entities include payroll calculations, deductions, and the roles of various stakeholders such as accountants and HR specialists, all of which interact to ensure accurate and timely payroll processing.
#
# ## Impact of Deductions on Payroll
#
# Deductions play a crucial role in determining the final payroll amount, as they reduce the gross salary of employees. This relationship highlights the importance of accurate deduction calculations to ensure employees receive the correct net pay. The integration of deductions into the payroll process is essential for compliance with financial obligations and employee satisfaction. [Data: Entities (271, 41); Relationships (331)]
#
# ## Role of Payroll Accountants
#
# Payroll accountants, specifically those in the role of 'ГБ. БУХГАЛТЕР РАСЧЕТНОЙ ГРУППЫ', are responsible for various critical tasks, including payroll calculations, adjustments, and the registration of benefits. Their involvement in the payroll process ensures that all financial operations are conducted accurately and in compliance with regulations. This role is pivotal in maintaining the integrity of payroll data and facilitating timely payments to employees. [Data: Entities (64); Relationships (1613, 1848, 111)]
#
# ## Importance of Time Sheets
#
# Time sheets, represented by the 'ТАБЕЛЬ-НАРЯД', are essential for recording employee work hours and calculating payroll. They serve as a foundational document for payroll processing, ensuring that all hours worked are accurately accounted for. The relationship between time sheets and payroll calculations underscores the need for precise data entry and verification to avoid discrepancies in employee payments. [Data: Entities (65); Relationships (75, 73)]
#
# ## Compliance with Labor Regulations
#
# The community's documentation processes must adhere to labor regulations, which dictate the timelines for payroll processing and the accuracy of deductions. The 'КОНТРОЛЬНЫЕ СРОКИ ВЫПОЛНЕНИЯ КЛЮЧЕВЫХ РАБОТ' define the deadlines for correcting payroll errors, emphasizing the need for timely and accurate documentation to avoid legal repercussions. This compliance aspect is critical for maintaining organizational integrity and employee trust. [Data: Entities (1193); Relationships (1848)]
#
# ## Integration of Additional Income
#
# Additional income is factored into the overall payroll calculations, affecting the total compensation employees receive. This integration requires careful documentation and tracking to ensure that all forms of compensation are accurately reflected in payroll reports. The relationship between additional income and payroll highlights the complexity of payroll management and the need for robust documentation practices. [Data: Entities (274); Relationships (313)]
